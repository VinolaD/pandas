# %% [markdown]
# # 03/08/2024

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Airbnb_updated (1).csv")
df
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 3     10006546              House  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df.sort_values(["bedrooms"],ascending=False).head(10)
# Out:
#            _id       property_type        room_type  bed_type  minimum_nights  \
# 2011  20701559      Boutique hotel     Private room  Real Bed               1
# 3684  27383511               Hotel     Private room  Real Bed               1
# 4437   3410502   Bed and breakfast  Entire home/apt  Real Bed               1
# 2178  20958766           Townhouse  Entire home/apt  Real Bed               2
# 358   12509339               House  Entire home/apt  Real Bed               1
# 4718   4742607           Farm stay  Entire home/apt  Real Bed               3
# 4121  31191629           Apartment  Entire home/apt  Real Bed               1
# 5511   9917859           Apartment  Entire home/apt  Real Bed               1
# 2690  23219274  Serviced apartment  Entire home/apt  Real Bed               1
# 4445  32838638           Apartment  Entire home/apt  Real Bed               1
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.sort_values(["bedrooms"],ascending=False).head(10).reset_index(drop=True)
# Out:
#         _id       property_type        room_type  bed_type  minimum_nights  \
# 0  20701559      Boutique hotel     Private room  Real Bed               1
# 1  27383511               Hotel     Private room  Real Bed               1
# 2   3410502   Bed and breakfast  Entire home/apt  Real Bed               1
# 3  20958766           Townhouse  Entire home/apt  Real Bed               2
# 4  12509339               House  Entire home/apt  Real Bed               1
# 5   4742607           Farm stay  Entire home/apt  Real Bed               3
# 6  31191629           Apartment  Entire home/apt  Real Bed               1
# 7   9917859           Apartment  Entire home/apt  Real Bed               1
# 8  23219274  Serviced apartment  Entire home/apt  Real Bed               1
# 9  32838638           Apartment  Entire home/apt  Real Bed               1
#
#    maximum_nights          cancellation_policy  accommodates  bedrooms  beds  \
# ...

# %%
df.sort_values(["bedrooms"],ascending=True).tail(10).reset_index(drop=True)
# Out:
#         _id       property_type        room_type  bed_type  minimum_nights  \
# 0  20955863               Villa  Entire home/apt  Real Bed               2
# 1  23219274  Serviced apartment  Entire home/apt  Real Bed               1
# 2  31191629           Apartment  Entire home/apt  Real Bed               1
# 3   9917859           Apartment  Entire home/apt  Real Bed               1
# 4   4742607           Farm stay  Entire home/apt  Real Bed               3
# 5  12509339               House  Entire home/apt  Real Bed               1
# 6  20958766           Townhouse  Entire home/apt  Real Bed               2
# 7   3410502   Bed and breakfast  Entire home/apt  Real Bed               1
# 8  27383511               Hotel     Private room  Real Bed               1
# 9  20701559      Boutique hotel     Private room  Real Bed               1
#
#    maximum_nights          cancellation_policy  accommodates  bedrooms  beds  \
# ...

# %%
df.iloc[5000:5550]
# Out:
#           _id      property_type        room_type  bed_type  minimum_nights  \
# 5000  6671678          Apartment  Entire home/apt  Real Bed               1
# 5001  6670191          Apartment  Entire home/apt  Real Bed              30
# 5002  6774703          Apartment     Private room  Real Bed               1
# 5003  6667210          Apartment  Entire home/apt  Real Bed               1
# 5004  6767563        Condominium  Entire home/apt  Real Bed               1
# ...       ...                ...              ...       ...             ...
# 5545  9849915          Apartment     Private room  Real Bed               2
# 5546  9936016          Apartment  Entire home/apt  Real Bed               1
# 5547  9944044  Bed and breakfast     Private room  Real Bed               2
# 5548  9908871              House  Entire home/apt  Real Bed               1
# 5549  9590866          Apartment     Private room  Real Bed               1
#
# ...

# %%
df.iloc[5000:5550:5]
# Out:
#           _id property_type        room_type  bed_type  minimum_nights  \
# 5000  6671678     Apartment  Entire home/apt  Real Bed               1
# 5005  6757263     Apartment     Private room  Real Bed               2
# 5010  6670684   Condominium  Entire home/apt  Real Bed               1
# 5015  6836536     Apartment  Entire home/apt  Real Bed               2
# 5020  6808336     Apartment     Private room  Real Bed               3
# ...       ...           ...              ...       ...             ...
# 5525  9987200    Aparthotel     Private room  Real Bed               3
# 5530  9714401         House  Entire home/apt  Real Bed               4
# 5535  9767864         House     Private room  Real Bed               2
# 5540  9774127     Apartment  Entire home/apt  Real Bed               4
# 5545  9849915     Apartment     Private room  Real Bed               2
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.iloc[5000:5550:5, 3:9]
# Out:
#       bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 5000  Real Bed               1            1125                     flexible
# 5005  Real Bed               2              20                     moderate
# 5010  Real Bed               1            1125  strict_14_with_grace_period
# 5015  Real Bed               2            1125  strict_14_with_grace_period
# 5020  Real Bed               3            1125                     moderate
# ...        ...             ...             ...                          ...
# 5525  Real Bed               3              60                     flexible
# 5530  Real Bed               4              60  strict_14_with_grace_period
# 5535  Real Bed               2              29  strict_14_with_grace_period
# 5540  Real Bed               4              90  strict_14_with_grace_period
# 5545  Real Bed               2              15                     moderate
#
#       accommodates  bedrooms
# ...

# %%
df.iloc[[25,60,5000,87], 3:]
# Out:
#       bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 25    Real Bed               1            1125  strict_14_with_grace_period
# 60    Real Bed               1            1125  strict_14_with_grace_period
# 5000  Real Bed               1            1125                     flexible
# 87    Real Bed               2              30  strict_14_with_grace_period
#
#       accommodates  bedrooms  beds  number_of_reviews  bathrooms  price  ...  \
# 25               2         1     1                  0          1    361  ...
# 60               4         1     2                 18          1    353  ...
# 5000             2         1     1                  0          1     44  ...
# 87               2         1     1                103          1    185  ...
#
#       host_total_listings_count          market        country  longitude  \
# 25                            6       Hong Kong      Hong Kong  114.17158
# ...

# %%
df.iloc[[25,60,5000,87], 3:25]
# Out:
#       bed_type  minimum_nights  maximum_nights          cancellation_policy  \
# 25    Real Bed               1            1125  strict_14_with_grace_period
# 60    Real Bed               1            1125  strict_14_with_grace_period
# 5000  Real Bed               1            1125                     flexible
# 87    Real Bed               2              30  strict_14_with_grace_period
#
#       accommodates  bedrooms  beds  number_of_reviews  bathrooms  price  ...  \
# 25               2         1     1                  0          1    361  ...
# 60               4         1     2                 18          1    353  ...
# 5000             2         1     1                  0          1     44  ...
# 87               2         1     1                103          1    185  ...
#
#       review_scores  cleaning_fee  host_response_time  host_response_rate  \
# 25                0             0      within an hour                90.0
# ...

# %%
df[df.property_type=="Townhouse"]
# Out:
#            _id property_type        room_type  bed_type  minimum_nights  \
# 149    1092760     Townhouse  Entire home/apt  Real Bed               7
# 158   11113983     Townhouse  Entire home/apt  Real Bed               1
# 314   11778959     Townhouse     Private room  Real Bed               2
# 337   12762087     Townhouse  Entire home/apt  Real Bed               2
# 379      12937     Townhouse     Private room  Real Bed               3
# ...        ...           ...              ...       ...             ...
# 5316   8634239     Townhouse  Entire home/apt  Real Bed               2
# 5441   9415438     Townhouse     Private room  Real Bed               2
# 5475   9562872     Townhouse  Entire home/apt  Real Bed               2
# 5477   9815988     Townhouse     Private room  Real Bed               7
# 5526   9993190     Townhouse  Entire home/apt  Real Bed               3
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.loc[:,["property_type","room_type","bed_type","minimum_nights"]]
# Out:
#           property_type        room_type  bed_type  minimum_nights
# 0             Apartment  Entire home/apt  Real Bed               1
# 1             Apartment     Private room  Real Bed              14
# 2             Apartment  Entire home/apt  Real Bed               2
# 3                 House  Entire home/apt  Real Bed               2
# 4             Apartment  Entire home/apt  Real Bed               2
# ...                 ...              ...       ...             ...
# 5550  Bed and breakfast     Private room  Real Bed               1
# 5551          Apartment     Private room  Real Bed               3
# 5552          Apartment  Entire home/apt  Real Bed               5
# 5553          Apartment     Private room  Real Bed               1
# 5554          Apartment  Entire home/apt  Real Bed               3
#
# [5555 rows x 4 columns]

# %%
df[df.availability_365>=300]
# Out:
#            _id       property_type        room_type  bed_type  minimum_nights  \
# 5      1001265         Condominium  Entire home/apt  Real Bed               3
# 9     10133554   Bed and breakfast     Private room  Real Bed               1
# 10    10138784           Apartment     Private room  Real Bed               2
# 15    10047964               House  Entire home/apt  Real Bed               2
# 16    10115921  Serviced apartment  Entire home/apt  Real Bed               1
# ...        ...                 ...              ...       ...             ...
# 5547   9944044   Bed and breakfast     Private room  Real Bed               2
# 5550   9799412   Bed and breakfast     Private room  Real Bed               1
# 5551   9887054           Apartment     Private room  Real Bed               3
# 5553   9981541           Apartment     Private room  Real Bed               1
# 5554   9983221           Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df.room_type.value_counts()
# Out:
# room_type
# Entire home/apt    3489
# Private room       1983
# Shared room          83
# Name: count, dtype: int64

# %%
df[df.availability_365.between(360,400)]
# Out:
#            _id       property_type        room_type  bed_type  minimum_nights  \
# 9     10133554   Bed and breakfast     Private room  Real Bed               1
# 10    10138784           Apartment     Private room  Real Bed               2
# 15    10047964               House  Entire home/apt  Real Bed               2
# 16    10115921  Serviced apartment  Entire home/apt  Real Bed               1
# 23    10116256  Serviced apartment  Entire home/apt  Real Bed               1
# ...        ...                 ...              ...       ...             ...
# 5533   9677123           Apartment  Entire home/apt  Real Bed               1
# 5537   9703075           Apartment  Entire home/apt  Real Bed               7
# 5547   9944044   Bed and breakfast     Private room  Real Bed               2
# 5550   9799412   Bed and breakfast     Private room  Real Bed               1
# 5553   9981541           Apartment     Private room  Real Bed               1
#
# ...
